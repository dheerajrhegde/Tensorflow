# %% [markdown]
# <a href="https://www.kaggle.com/code/dheerajrhegde/tensorflow-hello-world?scriptVersionId=147680014" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
tf.__version__
# Out:
# '2.12.0'

# %%
def get_y(x):
    ret = []
    for i in x:
        ret.append(2*i-1)
    return np.array(ret)

X = np.array([-1,0,1,2,3,4],dtype="float")
y = get_y(X)
print(X)
print(y)
# Out:
# [-1.  0.  1.  2.  3.  4.]
# [-3. -1.  1.  3.  5.  7.]

# %%
model = tf.keras.Sequential(
    [ keras.layers.Dense(units=1, input_shape=[1]) ]
)
model.compile(optimizer="sgd", loss="mean_squared_error")
model.fit(X, y, epochs=100)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 0s 486ms/step - loss: 33.7568
# Epoch 2/100
# 1/1 [==============================] - 0s 6ms/step - loss: 26.8873
# Epoch 3/100
# 1/1 [==============================] - 0s 7ms/step - loss: 21.4760
# Epoch 4/100
# 1/1 [==============================] - 0s 7ms/step - loss: 17.2120
# Epoch 5/100
# 1/1 [==============================] - 0s 8ms/step - loss: 13.8508
# Epoch 6/100
# 1/1 [==============================] - 0s 7ms/step - loss: 11.2000
# Epoch 7/100
# 1/1 [==============================] - 0s 8ms/step - loss: 9.1083
# Epoch 8/100
# 1/1 [==============================] - 0s 7ms/step - loss: 7.4565
# Epoch 9/100
# 1/1 [==============================] - 0s 7ms/step - loss: 6.1510
# Epoch 10/100
# 1/1 [==============================] - 0s 7ms/step - loss: 5.1181
# Epoch 11/100
# 1/1 [==============================] - 0s 8ms/step - loss: 4.2997
# Epoch 12/100
# 1/1 [==============================] - 0s 9ms/step - loss: 3.6502
# Epoch 13/100
# 1/1 [==============================] - 0s 7ms/step - loss: 3.1337
# Epoch 14/100
# 1/1 [==============================] - 0s 7ms/step - loss: 2.7220
# Epoch 15/100
# 1/1 [==============================] - 0s 8ms/step - loss: 2.3928
# Epoch 16/100
# 1/1 [==============================] - 0s 9ms/step - loss: 2.1286
# Epoch 17/100
# 1/1 [==============================] - 0s 7ms/step - loss: 1.9158
# Epoch 18/100
# 1/1 [==============================] - 0s 8ms/step - loss: 1.7433
# Epoch 19/100
# 1/1 [==============================] - 0s 7ms/step - loss: 1.6028
# Epoch 20/100
# 1/1 [==============================] - 0s 9ms/step - loss: 1.4875
# Epoch 21/100
# 1/1 [==============================] - 0s 7ms/step - loss: 1.3922
# Epoch 22/100
# 1/1 [==============================] - 0s 8ms/step - loss: 1.3126
# Epoch 23/100
# 1/1 [==============================] - 0s 7ms/step - loss: 1.2455
# Epoch 24/100
# 1/1 [==============================] - 0s 9ms/step - loss: 1.1884
# Epoch 25/100
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1391
# Epoch 26/100
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0962
# Epoch 27/100
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0583
# Epoch 28/100
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0245
# Epoch 29/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.9939
# Epoch 30/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.9660
# Epoch 31/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.9403
# Epoch 32/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.9163
# Epoch 33/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.8939
# Epoch 34/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.8726
# Epoch 35/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.8525
# Epoch 36/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.8332
# Epoch 37/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.8147
# Epoch 38/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.7968
# Epoch 39/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.7796
# Epoch 40/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.7629
# Epoch 41/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.7467
# Epoch 42/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.7309
# Epoch 43/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.7156
# Epoch 44/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.7006
# Epoch 45/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.6860
# Epoch 46/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6718
# Epoch 47/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.6579
# Epoch 48/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.6443
# Epoch 49/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.6309
# Epoch 50/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6179
# Epoch 51/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.6052
# Epoch 52/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.5927
# Epoch 53/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.5805
# Epoch 54/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.5686
# Epoch 55/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.5569
# Epoch 56/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.5454
# Epoch 57/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.5342
# Epoch 58/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.5232
# Epoch 59/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.5125
# Epoch 60/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.5019
# Epoch 61/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4916
# Epoch 62/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4815
# Epoch 63/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4716
# Epoch 64/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.4619
# Epoch 65/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4524
# Epoch 66/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4431
# Epoch 67/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4340
# Epoch 68/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4251
# Epoch 69/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4164
# Epoch 70/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4078
# Epoch 71/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3995
# Epoch 72/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3913
# Epoch 73/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3832
# Epoch 74/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3753
# Epoch 75/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3676
# Epoch 76/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3601
# Epoch 77/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3527
# Epoch 78/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3454
# Epoch 79/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3383
# Epoch 80/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3314
# Epoch 81/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3246
# Epoch 82/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3179
# Epoch 83/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3114
# Epoch 84/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3050
# Epoch 85/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2987
# Epoch 86/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2926
# Epoch 87/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2866
# Epoch 88/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2807
# Epoch 89/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2749
# Epoch 90/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2693
# Epoch 91/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2638
# Epoch 92/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2583
# Epoch 93/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2530
# Epoch 94/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2478
# Epoch 95/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2427
# Epoch 96/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2378
# Epoch 97/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2329
# Epoch 98/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2281
# Epoch 99/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2234
# Epoch 100/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2188
